# %%
import sys
sys.path.append('scripts')
from importlib import reload
import fonction

df = fonction.load_match('data/ligue1/3900563.json')

print(df)
# Out:
#                                         id  index  period     timestamp  \
# 0     78d3a950-2d44-41ad-9c91-a0a3ccda986f      1       1  00:00:00.000
# 1     8f4c91fb-3272-44a8-bff9-1f4c44a14e86      2       1  00:00:00.000
# 2     6892857c-7be4-4e33-90d6-a62fbb7ac2d5      3       1  00:00:00.000
# 3     32657f57-7b19-48c2-9a4a-1da1de48cdaa      4       1  00:00:00.000
# 4     7d7ea69a-8ec0-403d-89eb-d0bfe16636a8      5       1  00:00:01.337
# ...                                    ...    ...     ...           ...
# 3167  f9aca32b-7610-4815-9545-17707d8c5e0a   3168       2  00:49:32.714
# 3168  ce914436-692b-4891-bae4-385e02a091c7   3169       2  00:49:33.080
# 3169  8821a03c-2850-404f-895b-176d33f1e5e5   3170       2  00:49:33.843
# 3170  15820ec3-e97e-4347-84ab-b32719e33eb0   3171       2  00:49:35.505
# 3171  9e8915f4-d383-45a8-a266-e192a012df4a   3172       2  00:49:35.505
#
#       minute  second  possession  duration  type.id    type.name  ...  \
# ...

# %%
colonnes_joueurs = [col for col in df.columns if 'player' in col.lower()]
print(colonnes_joueurs)
print(df['player.name'].dropna().unique())
# Out:
# ['player.id', 'player.name']
# ['Giovanni-Guy Yann Sio' 'Juan Fernando Quintero Paniagua'
#  'Sylvain Armand' 'Pedro Henrique Konzen Medina da Silva' 'Jonas Lössl'
#  'Moustapha Elhadji Diallo' 'Benjamin André' 'Jonathan Martins-Pereira'
#  'Marcus Coco' "Cheikh M''Bengue" 'Jimmy Briand' 'Younousse Sankharé'
#  'Yannis Salibur' 'Romain Danzé' 'Ousmane Dembélé' 'Christophe Kerbrat'
#  'Gélson da Conceição Tavares Fernandes' 'Lionel Mathis' 'Fallou Diagne'
#  'Jérémy Sorbon' 'Laurent Dos Santos' 'Benoît Guy Robert Costil'
#  'Sloan Privat' 'Nicolas Benezet' 'Abdoulaye Doucouré' 'Steven Moreira'
#  'Nicolas Janvier']
